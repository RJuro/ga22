# %% [markdown]
# <a href="https://colab.research.google.com/github/RJuro/ga22/blob/main/ga22/tutorials/BERTopic_Cordis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BERTopic for Topic Modeling with CORDIS data.
#
# [BERTopic](https://maartengr.github.io/BERTopic/index.html) can be considered the current (2022) state of the art in topic modeling. You'll find the corresponding [paper here](https://arxiv.org/abs/2203.05794).
# It's advantage lies in a clever use of [sentence transfomers](https://www.sbert.net/) as well as dimensionality reduction and clustering (per default UMAP and HDBSCAN).
# Sentence transformers allow to encode natural language efficiently (also very large amounts). UMAP and HDBSCAN are two high-performance algorithms.
# The autor Maarten Grootendorst released a well documented and increasingly used package that implements all steps including useful visualization and representation tool.
#
# In this tutorial we will use the approach to identify topics in CORDIS data (EU FP and H2020 project results).
# This is a basic-application tutorial adjusted to work for "smaller data" (500 summaries) following [this tutorial](https://www.kaggle.com/code/maartengr/topic-modeling-arxiv-abstract-with-bertopic/notebook).
#
# Also: We are going to use a GPU enabled instance... You get very far with Google Colab (clear legal first)

# %%
# Start by installing the package (in quite mode)
# !pip install bertopic -q
# Out:
#      |████████████████████████████████| 76 kB 1.7 MB/s
#      |████████████████████████████████| 636 kB 11.3 MB/s
#      |████████████████████████████████| 88 kB 5.7 MB/s
#      |████████████████████████████████| 5.2 MB 51.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 85 kB 5.1 MB/s
#      |████████████████████████████████| 4.7 MB 46.9 MB/s
#      |████████████████████████████████| 1.3 MB 59.4 MB/s
#      |████████████████████████████████| 101 kB 11.9 MB/s
#      |████████████████████████████████| 6.6 MB 41.3 MB/s
#      |████████████████████████████████| 1.1 MB 60.1 MB/s
#   Building wheel for hdbscan (PEP 517) ... done
#   Building wheel for sentence-transformers (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %%
# Colab specific widget handling
from google.colab import output
output.enable_custom_widget_manager()

# %%
# Load packages for the analysis
import pandas as pd #handling / opening data
import random #create random years (this table does not have clear years)

from bertopic import BERTopic
from hdbscan import HDBSCAN
from umap import UMAP

from sklearn.feature_extraction.text import CountVectorizer

# %%
# Load report-data
reports = pd.read_csv('https://github.com/SDS-AAU/SDS-master/raw/master/M2/data/cordis-h2020reports.gz')

# %%
years = pd.to_datetime(reports.lastUpdateDate)

# %%
set([y.year for y in years])
# Out:
# {nan, 2017, 2018, 2019}

# %%
# creating "fake years" for this tutorial...don't do that in a real analysis :-)
reports['year'] = [random.choice(range(2010,2018)) for _ in range(len(reports))]

# %%
reports['summary']
# Out:
# 0      Polyaniline has historically been one of the m...
# 1      Problem/issue: Increasing digitalisation enabl...
# 2      At a time of public budget constraints, major ...
# 3      Espresso coffee has always been closely associ...
# 4      The primary industrial objective of the PLEIAD...
#                              ...
# 495    HEMAV, a technology-based SME leader in civil ...
# 496    The ultimate objective of the Celletest projec...
# 497    Magnesium deficiency is a global issue which a...
# 498    The main objective of the MEMO project is to c...
# 499    Hydrophobic surfaces have significant potentia...
# Name: summary, Length: 500, dtype: object

# %% [markdown]
# We need to specify a few things to make the approach work in our setting.
# This will involve:
#
#
#
# *   Use a custom vectorizer that will remove stop-words (e.g. the, and, to, I)
# *   Tweak UMAP and HDBSCAN to produce more and more specific clusters (check BERTopic FAQ and documentation)
# * Request use fo n-grams from BERTopics for "reporting"
# * use of specialized allenai-specter trasformer pretrained to deal with scientific text

# %%
# custom vectorizer to get rid of stopwords
vectorizer_model = CountVectorizer(stop_words="english")

# lower n_neighbors=3 value thatn standard 5 and lower n_components=3
umap_model = UMAP(n_neighbors=3, n_components=3, 
                  min_dist=0.0, metric='cosine', random_state=42)

# resuce min_cluster_size and min_samples
hdbscan_model = HDBSCAN(min_cluster_size=20, metric='euclidean', 
                        cluster_selection_method='eom', prediction_data=True, min_samples=3)

# specify all custom models and n_grams
topic_model = BERTopic(verbose=True, 
                       embedding_model="allenai-specter", 
                       n_gram_range=(2, 3), 
                       hdbscan_model=hdbscan_model, 
                       umap_model=umap_model,
                       vectorizer_model=vectorizer_model)

# %%
# Run the modelnig
topics, _ = topic_model.fit_transform(reports['summary']); len(topic_model.get_topic_info())
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.71k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/622 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/462k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/331 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/222k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Batches:   0%|          | 0/16 [00:00<?, ?it/s]
# 2022-08-21 09:35:22,778 - BERTopic - Transformed documents to Embeddings
# 2022-08-21 09:35:30,834 - BERTopic - Reduced dimensionality
# 2022-08-21 09:35:30,863 - BERTopic - Clustered reduced embeddings
# 11

# %% [markdown]
# the object `topics` is a vector with the cluster-numbers that can be used in other analysis...

# %% [markdown]
# Below some built-in ways for exploring the results

# %%
topic_model.get_topic_info().head(10)
# Out:
#    Topic  Count                                  Name
# 0     -1     39          -1_rail_plant_project_plants
# 1      0    131          0_cells_project_cell_disease
# 2      1     96     1_energy_market_materials_project
# 3      2     46         2_innovation_support_sme_smes
# 4      3     39   3_researchers_science_people_social
# 5      4     34        4_quantum_project_spin_optical
# 6      5     26        5_process_sensor_software_data
# 7      6     24          6_data_research_eo_knowledge
# 8      7     24   7_water_wastewater_lignin_treatment
# 9      8     21  8_fish_aircraft_european_aquaculture

# %%
topic_model.visualize_barchart(top_n_topics=9, height=200)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="213da962-bbd9-4ec2-bd98-30ad3bff677d" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("213da962-bbd9-4ec2-bd98-30ad3bff677d")) {                    Plotly.newPlot(                        "213da962-bbd9-4ec2-bd98-30ad3bff677d",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.015263595506927016,0.01817340563300259,0.019606059252901514,0.0200740565443117,0.02256207008837623],"y":["research  ","disease  ","cell  ","project  ","cells  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.01920843985744779,0.02221510344275411,0.022721176940847514,0.023349542481678656,0.0324950009166909],"y":["high  ","project  ","materials  ","market  ","energy  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.02533134391855419,0.029161198111904617,0.029216721844264954,0.029909930752973823,0.046125503560820624],"y":["management  ","smes  ","sme  ","support  ","innovation  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.01838675724024875,0.021914553334339112,0.02279928547281341,0.02537530201973087,0.025715816838944753],"y":["public  ","social  ","people  ","science  ","researchers  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.02306030270955877,0.025603995309503923,0.026722268418225253,0.02697424116326966,0.05183599856690394],"y":["systems  ","optical  ","spin  ","project  ","quantum  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.026254344625292317,0.027209048540945954,0.030954302381264738,0.03195613329276033,0.03199507293773134],"y":["industrial  ","data  ","software  ","sensor  ","process  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.02306261885896846,0.02375099863552152,0.024857521043065538,0.0341056952600057,0.03421571778371201],"y":["eu  ","knowledge  ","eo  ","research  ","data  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.026587234973937394,0.0266145600732305,0.027485951507099243,0.027485951507099243,0.07604843288702529],"y":["oil  ","treatment  ","lignin  ","wastewater  ","water  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.026842964073872794,0.027316457613971015,0.033132128522194826,0.05290321932366294,0.053963162169971254],"y":["marine  ","aquaculture  ","european  ","aircraft  ","fish  "],"type":"bar","xaxis":"x9","yaxis":"y9"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777 ...

# %%
topic_model.visualize_topics(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2e354c4c-fbc5-469a-8209-2ed3829cc9b3" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e354c4c-fbc5-469a-8209-2ed3829cc9b3")) {                    Plotly.newPlot(                        "2e354c4c-fbc5-469a-8209-2ed3829cc9b3",                        [{"customdata":[[0,"cells | project | cell | disease | research",131],[1,"energy | market | materials | project | high",96],[2,"innovation | support | sme | smes | management",46],[3,"researchers | science | people | social | public",39],[4,"quantum | project | spin | optical | systems",34],[5,"process | sensor | software | data | industrial",26],[6,"data | research | eo | knowledge | eu",24],[7,"water | wastewater | lignin | treatment | oil",24],[8,"fish | aircraft | european | aquaculture | marine",21],[9,"cloud | security | data | applications | networks",20]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>Words: %{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[131,96,46,39,34,26,24,24,21,20],"sizemode":"area","sizeref":0.081875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[22.857574462890625,22.990341186523438,4.010109901428223,3.702105760574341,22.353055953979492,-5.72124719619751,4.3614702224731445,23.42938804626465,4.6339030265808105,-5.973700523376465],"xaxis":"x","y":[8.356668472290039,7.715256690979004,15.763794898986816,15.421736717224121,7.778988361358643,-10.257922172546387,16.136960983276367,8.010644912719727,16.377256393432617,-10.510374069213867],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"# ...

# %%
topic_model.visualize_hierarchy(top_n_topics=50, width=800)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b65ec268-35c7-45d7-ab0c-bddec4f3ac56" class="plotly-graph-div" style="height:350px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b65ec268-35c7-45d7-ab0c-bddec4f3ac56")) {                    Plotly.newPlot(                        "b65ec268-35c7-45d7-ab0c-bddec4f3ac56",                        [{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.0041782281348057,1.0041782281348057,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6827282495808074,0.6827282495808074,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.7544361431397708,0.7544361431397708,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.6827282495808074,0.8035850399981426,0.8035850399981426,0.7544361431397708],"xaxis":"x","y":[-30.0,-30.0,-50.0,-50.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.7173200099539756,0.7173200099539756,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8714305971930739,0.8714305971930739,0.7173200099539756],"xaxis":"x","y":[-65.0,-65.0,-80.0,-80.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.8714305971930739,0.8942827945502668,0.8942827945502668,0.0],"xaxis":"x","y":[-72.5,-72.5,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8035850399981426,1.02560008916953,1.02560008916953,0.8942827945502668],"xaxis":"x","y":[-40.0,-40.0,-83.75,-83.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.0041782281348057,1.0926603015756498,1.0926603015756498,1.02560008916953],"xaxis":"x","y":[-10.0,-10.0,-61.875,-61.875],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":350,"hovermode":"closest","showlegend":false,"width":800,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["7_water_wastewater_lignin","8_fish_aircraft_european","6_data_research_eo","2_innovation_support_sme","0_cells_project_cell","3_researchers_science_people","4_quantum_project_spin","1_energy_market_materials","5_process_sensor_software","9_cloud_security_data"],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0,-65.0,-75.0,-85.0,-95.0],"type":"linear","zeroline":false,"range":[-100.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth": ...

# %%
# dynamic analysis with "fake years"
topics_over_time = topic_model.topics_over_time(reports['summary'], topics, reports['year'])
topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=20, width=900, height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3a612065-a806-4bcc-b3ef-9d6a18825ba8" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a612065-a806-4bcc-b3ef-9d6a18825ba8")) {                    Plotly.newPlot(                        "3a612065-a806-4bcc-b3ef-9d6a18825ba8",                        [{"hoverinfo":"text","hovertext":["<b>Topic -1</b><br>Words: content, group, plant, recap, black","<b>Topic -1</b><br>Words: plants, infection, gfp, vaccine, mir395","<b>Topic -1</b><br>Words: gr, rail, stress, project, ads","<b>Topic -1</b><br>Words: parasites, vaccines, parasite, multicellular, immunity","<b>Topic -1</b><br>Words: rail, wheat, infrastructure, breeding, genetic","<b>Topic -1</b><br>Words: fe, galaxies, characteristic, signature, iron","<b>Topic -1</b><br>Words: plant, k\u00e4hler, growth, anthrax, metric","<b>Topic -1</b><br>Words: digitization, sensing, film, fibre, solution"],"marker":{"color":"#E69F00"},"mode":"lines","name":"-1_rail_plant_project_plants","x":[2010,2011,2012,2013,2014,2015,2016,2017],"y":[7,6,7,1,3,5,8,2],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: energy, market, materials, project, high","<b>Topic 1</b><br>Words: energy, project, charging, music, electrical","<b>Topic 1</b><br>Words: market, energy, high, cost, project","<b>Topic 1</b><br>Words: air, materials, energy, project, scale","<b>Topic 1</b><br>Words: energy, material, project, food, design","<b>Topic 1</b><br>Words: energy, materials, project, market, based","<b>Topic 1</b><br>Words: materials, technology, conductive, data, paniplast","<b>Topic 1</b><br>Words: energy, buildings, materials, batteries, consumption"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_energy_market_materials_project","x":[2010,2011,2012,2013,2014,2015,2016,2017],"y":[17,11,15,14,14,16,4,5],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: care, soil, innovation, integrated, initiatives","<b>Topic 2</b><br>Words: innovation, support, data, smes, management","<b>Topic 2</b><br>Words: innovation, research, sme, services, smes","<b>Topic 2</b><br>Words: innovation, social, smes, food, surgical","<b>Topic 2</b><br>Words: clinical, trial, trials, esil, monitoring","<b>Topic 2</b><br>Words: innovation, support, sme, management, research","<b>Topic 2</b><br>Words: innovation, services, border, soil, veh","<b>Topic 2</b><br>Words: data, innovation, sme, support, project"],"marker":{"color":"#009E73"},"mode":"lines","name":"2_innovation_support_sme_smes","x":[2010,2011,2012,2013,2014,2015,2016,2017],"y":[4,6,6,4,3,8,4,11],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 3</b><br>Words: children, cyclists, people, users, caregiverspro","<b>Topic 3</b><br>Words: transport, cablesmart, traffic, environment, ite","<b>Topic 3</b><br>Words: science, people, road, researchers, grape","<b>Topic 3</b><br>Words: asr, av, tutorfair, recognition, speech","<b>Topic 3</b><br>Words: translation, learning, smash, unbabel, science","<b>Topic 3</b><br>Words: science, hpe, students, researchers, social","<b>Topic 3</b><br>Words: parking, bicycle, bicycles, researchers, use","<b>Topic 3</b><br>Words: glass, social, human, researchers, based"],"marker":{"color":"#F0E442"},"mode":"lines","name":"3_researchers_science_people_social","x":[2010,2011,2012,2013,2014,2015,2016,2017],"y":[4,2,5,4,7,4,5,8],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 4</b><br>Words: quantum, magnetic, superconducting, circuits, properties","<b>Topic 4</b><br>Words: quantum, optical, project, cnt, data","<b>Topic 4</b><br>Words: mixmax, generators, carlo, monte, quantum","<b>Topic 4</b><br>Words: permeabilization, membranes, bioem, phospholipids, peroxidation","<b>Topic 4</b><br> ...

# %% [markdown]
# You can also use BERTopic to generate embeddings and use them in other analysis...for instance some supervised task. However, it is probably easier to go directly to SBERT (sentence transformers)

# %%
# create embeddings

docs = topic_model.embedding_model.embed_documents(reports['summary'])
